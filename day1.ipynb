# %%
import pandas as pd

# pandas is a library for working with data tables
# think of it like Excel but in Python

print("Day 2 — my ML journey starts now")
print("pandas version:", pd.__version__)
# Out:
# Day 2 — my ML journey starts now
# pandas version: 2.3.3
